# %% [markdown]
# <a href="https://colab.research.google.com/github/Skeo220/UCI-Machine-Learning-Repository/blob/main/Bank_Marketing_Feature_Engineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://github.com/uci-ml-repo/ucimlrepo

# %%
# !pip3 install -U ucimlrepo
# Out:
# Requirement already satisfied: ucimlrepo in /usr/local/lib/python3.10/dist-packages (0.0.3)

# %%
# import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ucimlrepo import fetch_ucirepo, list_available_datasets

# %%
# importing the dataset
bank_data = fetch_ucirepo(name='Bank Marketing')
features = bank_data.data.features
target = bank_data.data.targets

# %%
print(f'features shape:',features.shape)
print(f'target shape:',target.shape)
# Out:
# features shape: (45211, 16)
# target shape: (45211, 1)

# %%
# data types
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          45211 non-null  int64
#  1   job          44923 non-null  object
#  2   marital      45211 non-null  object
#  3   education    43354 non-null  object
#  4   default      45211 non-null  object
#  5   balance      45211 non-null  int64
#  6   housing      45211 non-null  object
#  7   loan         45211 non-null  object
#  8   contact      32191 non-null  object
#  9   day_of_week  45211 non-null  int64
#  10  month        45211 non-null  object
#  11  duration     45211 non-null  int64
#  12  campaign     45211 non-null  int64
#  13  pdays        45211 non-null  int64
#  14  previous     45211 non-null  int64
#  15  poutcome     8252 non-null   object
# dtypes: int64(7), object(9)
# memory usage: 5.5+ MB

# %%
features.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married        NaN      no     1506     yes   no
# 4   33           NaN   single        NaN      no        1      no   no
#
#   contact  day_of_week month  duration  campaign  pdays  previous poutcome
# 0     NaN            5   may       261         1     -1         0      NaN
# 1     NaN            5   may       151         1     -1         0      NaN
# 2     NaN            5   may        76         1     -1         0      NaN
# 3     NaN            5   may        92         1     -1         0      NaN
# 4     NaN            5   may       198         1     -1         0      NaN

# %%
# Split the numerical and categorical columns
num_vars = features.select_dtypes(include='int64')
cat_vars = features.select_dtypes(include='object')

# %%
num_vars.head()
# Out:
#    age  balance  day_of_week  duration  campaign  pdays  previous
# 0   58     2143            5       261         1     -1         0
# 1   44       29            5       151         1     -1         0
# 2   33        2            5        76         1     -1         0
# 3   47     1506            5        92         1     -1         0
# 4   33        1            5       198         1     -1         0

# %%
num_vars.describe()
# Out:
#                 age        balance   day_of_week      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       -1.000000      0.000000
# max      871.000000    275.000000

# %% [markdown]
# ### pdays

# %%
# bins and labels
bins = [-1, 100, 200, 300, 400, 500, float('inf')]
labels = ['<0', '0-100', '101-200', '201-300', '301-400', '>400']
num_vars['bin_pdays'] = pd.cut(num_vars['pdays'], bins=bins, labels=labels, right=False)
num_vars.head()
# Out:
#    age  balance  day_of_week  duration  campaign  pdays  previous bin_pdays
# 0   58     2143            5       261         1     -1         0        <0
# 1   44       29            5       151         1     -1         0        <0
# 2   33        2            5        76         1     -1         0        <0
# 3   47     1506            5        92         1     -1         0        <0
# 4   33        1            5       198         1     -1         0        <0

# %% [markdown]
# ### Previous
# We are going to bin this too

# %%
# bins and labels
bins = [0, 5, 10, 15, 20, 25, float('inf')]
labels = ['0', '1-5', '6-10', '11-15', '16-20', '>20']
num_vars['bin_previous'] = pd.cut(num_vars['previous'], bins=bins, labels=labels, right=False)
num_vars.head()
# Out:
#    age  balance  day_of_week  duration  campaign  pdays  previous bin_pdays  \
# 0   58     2143            5       261         1     -1         0        <0
# 1   44       29            5       151         1     -1         0        <0
# 2   33        2            5        76         1     -1         0        <0
# 3   47     1506            5        92         1     -1         0        <0
# 4   33        1            5       198         1     -1         0        <0
#
#   bin_previous
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %% [markdown]
# ### Campaign bins

# %%
# bins and labels
bins = [1, 5, 10, 15, 20, 25, 30, float('inf')]
labels = ['0-5', '6-10', '11-15', '16-20', '21-25', '26-30', '>30']
num_vars['bin_campaign'] = pd.cut(num_vars['campaign'], bins=bins, labels=labels, right=False)
num_vars.head()
# Out:
#    age  balance  day_of_week  duration  campaign  pdays  previous bin_pdays  \
# 0   58     2143            5       261         1     -1         0        <0
# 1   44       29            5       151         1     -1         0        <0
# 2   33        2            5        76         1     -1         0        <0
# 3   47     1506            5        92         1     -1         0        <0
# 4   33        1            5       198         1     -1         0        <0
#
#   bin_previous bin_campaign
# 0            0          0-5
# 1            0          0-5
# 2            0          0-5
# 3            0          0-5
# 4            0          0-5

# %%
num_vars.head()
# Out:
#    age  balance  day_of_week  duration  campaign  pdays  previous bin_pdays  \
# 0   58     2143            5       261         1     -1         0        <0
# 1   44       29            5       151         1     -1         0        <0
# 2   33        2            5        76         1     -1         0        <0
# 3   47     1506            5        92         1     -1         0        <0
# 4   33        1            5       198         1     -1         0        <0
#
#   bin_previous bin_campaign
# 0            0          0-5
# 1            0          0-5
# 2            0          0-5
# 3            0          0-5
# 4            0          0-5

# %%
cat_vars.head()
# Out:
#             job  marital  education default housing loan  contact month  \
# 0    management  married   tertiary      no     yes   no  unknown   may
# 1    technician   single  secondary      no     yes   no  unknown   may
# 2  entrepreneur  married  secondary      no     yes  yes  unknown   may
# 3   blue-collar  married    unknown      no     yes   no  unknown   may
# 4       unknown   single    unknown      no      no   no  unknown   may
#
#   poutcome
# 0  unknown
# 1  unknown
# 2  unknown
# 3  unknown
# 4  unknown

# %%
cat_vars.fillna('unknown', inplace=True)

# %%
cat_vars = pd.
